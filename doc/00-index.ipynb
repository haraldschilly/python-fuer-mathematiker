# %% [markdown]
# # Index

# %%
# %run res/index.py
mk_index()
# Out:
# <style>
# div.index > div {
# display: block;
# font-size: 135%;
# line-height: 140%;
# }
# div.index > div.minor {
# font-size: 125%;
# padding-left: 2em;
# }
# </style>
# <div class='index'>
#                     <div class='major'>
#                         §0 <a href='00-index.ipynb'>Index</a>
#                     </div>
#                     <div class='major'>
#                         §1 <a href='10-einfuehrung.ipynb'>Python Kurzeinführung</a>
#                     </div>
#                     <div class='minor'>
#                         §1.1 <a href='11-programmieren.ipynb'>Was ist Programmieren?</a>
#                     </div>
#                     <div class='minor'>
#                         §1.2 <a href='12-ipython.ipynb'>IPython Notebook</a>
#                     </div>
#                     <div class='major'>
#                         §2 <a href='20-konzepte.ipynb'>Konzepte</a>
#                     </div>
#                     <div class='minor'>
# ...
