# %% [markdown]
# # Index

# %%
mk_index()
# Out:
# <div class='index'>
#                     <div class='major'>
#                         §0 <a href='00-index.ipynb'>Index</a>
#                     </div>
#                     <div class='major'>
#                         §1 <a href='10-einfuehrung.ipynb'>Python Kurzeinführung</a>
#                     </div>
#                     <div class='minor'>
#                         §1.1 <a href='11-programmieren.ipynb'>Was ist Programmieren?</a>
#                     </div>
#                     <div class='minor'>
#                         §1.2 <a href='12-ipython.ipynb'>IPython Notebook</a>
#                     </div>
#                     <div class='major'>
#                         §2 <a href='20-konzepte.ipynb'>Konzepte</a>
#                     </div>
#                     <div class='minor'>
#                         §2.1 <a href='21-ausdruecke_und_variablen.ipynb'>Konzept 1: Ausdrücke und Variablen</a>
#                     </div>
#                     <div class='minor'>
#                         §2.2 <a href='22-syntax.ipynb'>Konzept 2: Syntax</a>
#                     </div>
#                     <div class='minor'>
#                         §2.3 <a href='23-funktionen.ipynb'>Konzept 3: Funktionen</a>
#                     </div>
#                     <div class='minor'>
#                         §2.4 <a href='24-kontrollstrukturen.ipynb'>Konzept 4: Kontrollstrukturen</a>
#                     </div>
#                     <div class='minor'>
#                         §2.5 <a href='25-datenstrukturen.ipynb'>Konzept 5: Datenstrukturen</a>
#                     </div>
#                     <div class='minor'>
#                         §2.6 <a href='26-datentypen_und_objekte.ipynb'>Konzept 6: Typen und Objekte</a>
#                     </div>
#                     <div class='minor'>
#                         §2.7 <a href='27-modularisierung.ipynb'>Konzept 7: Modularisierung</a>
#                     </div>
#                     <div class='major'>
#                         §3 <a href='30-mathematik.ipynb'>Mathematische Anwendungen</a>
#                     </div>
#                     <div class='minor'>
#                         §3.1 <a href='31-symbolisch_rechnen.ipynb'>Symbolisches Rechnen mit SymPy</a>
#                     </div>
#                     <div class='minor'>
#                         §3.2 <a href='32-numerik.ipynb'>Numerisches Rechnen mit NumPy/SciPy</a>
#                     </div>
#                     <div class='minor'>
#                         §3.3 <a href='33-zahlentheorie.ipynb'>Zahlentheorie</a>
#                     </div>
#                     <div class='minor'>
#                         §3.4 <a href='34-diskrete_mathematik.ipynb'>Diskrete Mathematik</a>
#                     </div>
#                     <div class='minor'>
#                         §3.5 <a href='35-grafische_darstellung.ipynb'>Grafische Darstellung</a>
#                     </div>
#                     <div class='minor'>
#                         §3.6 <a href='36-statistik.ipynb'>Statistik</a>
#                     </div>
#                     <div class='minor'>
#                         §3.7 <a href='37-geometrie.ipynb'>Geometrie</a>
#                     </div>
#                     <div class='minor'>
#                         §3.8 <a href='38-kryptographie.ipynb'>Kryptographie</a>
#                     </div>
#                     <div class='minor'>
#                         §3.9 <a href='39-logik.ipynb'>Logik</a>
#                     </div>
#                     <div class='major'>
#                         §4 <a href='40-programmiertechniken.ipynb'>Programmiertechniken</a>
#                     </div>
#                     <div class='minor'>
#                         §4.1 <a href='41-programme.ipynb'>Eigenständige Pythonprogramme</a>
#                     </div>
#                     <div class='minor'>
#                         §4.2 <a href='42-dokumentation.ipynb'>Dokumentation eines Programmes</a>
#                     </div>
#                     <div class='minor'>
#                         §4.3 <a href='43-daten.ipynb'>Daten, Dateiformate und Persistenz</a>
#                     </div>
#                     <div class='minor'>
#                         §4.4 <a href='44-qualitaetskontrolle.ipynb'>Qualitätskontrolle</a>
#                     </div>
#                     <div class='minor'>
#                         §4.5 <a href='45-netzwerk.ipynb'>Netzwerk und Internet</a>
#                     </div>
#                     <div class='minor'>
#                         §4.6 <a href='46-concurrency.ipynb'>Co-routinen, Threads & Subprozesse</a>
#                     </div>
#                     <div class='minor'>
#                         §4.7 <a href='47-debugging.ipynb'>Debugging</a>
#                     </div>
#                     <div class='major'>
#                         §5 <a href='50-links.ipynb'>Weiterführende Literatur und Links</a>
#                     </div>
#                     <div class='major'>
#                         §6 <a href='60-glossar.ipynb'>Glossar</a>
#                     </div>
#                     <div class='major'>
#                         §7 <a href='70-outro.ipynb'>Nachwort</a>
#                     </div></div>

# %%
from glob import glob
from IPython.nbformat import current

def extract_title(cell):
    """
    Extracts from a given cell in a notebook the <h1> title in a markdown content, if available,
    or the explicitly set heading of level 1 - otherwise None.
    """
    if cell["cell_type"] == "markdown":
        for line in cell["source"].splitlines():
            if line.startswith("# "):
                return line[2:]
    elif cell["cell_type"] == "heading" and cell["level"] == 1:
        return cell["source"]
    return None

def mk_index():
    out=u"<div class='index'>"
    for fn in sorted(glob("??-*.ipynb")):
        with open(fn) as f:
            nb = current.read(f, "ipynb")
            for cell in nb["worksheets"][0]["cells"]:
                title = extract_title(cell)
                if title:
                    break
                    
            title = title or fn[3:-6].title()
            major, minor = fn[:2]
            if int(minor) == 0:
                minor = ""
                cls = "major"
            else:
                minor = "." + minor
                cls = "minor"
            fn = fn.decode("utf8")
            out += u"""
                    <div class='{cls}'>
                        §{major}{minor} <a href='{fn}'>{title}</a>
                    </div>""".format(**locals())
    return HTML(out + u"</div>")

# %%
from IPython.display import HTML
HTML("""
<style>
div.index > div {
display: block;
font-size: 135%;
line-height: 140%;
}
div.index > div.minor {
font-size: 125%;
padding-left: 2em;
""")
# Out:
# <style>
# div.index > div {
# display: block;
# font-size: 135%;
# line-height: 140%;
# }
# div.index > div.minor {
# font-size: 125%;
# padding-left: 2em;
